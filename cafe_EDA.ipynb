# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("cleaned_cafe_sales.csv")

# %%
df.head()
# Out:
#    Item  Quantity  Price Per Unit  Total Spent  Payment Method  Location  \
# 0     0       2.0             2.0     4.000000     credit card  Takeaway
# 1     1       4.0             3.0    12.000000            cash  In-store
# 2     2       4.0             1.0     8.924352     credit card  In-store
# 3     3       2.0             5.0    10.000000         unknown   UNKNOWN
# 4     0       2.0             2.0     4.000000  digital wallet  In-store
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11

# %%
Observation:
   Dataset contains 5 rows and 7 columns 
   Data types were verified.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              10000 non-null  int64
#  1   Quantity          10000 non-null  float64
#  2   Price Per Unit    10000 non-null  float64
#  3   Total Spent       10000 non-null  float64
#  4   Payment Method    10000 non-null  object
#  5   Location          10000 non-null  object
#  6   Transaction Date  10000 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 547.0+ KB

# %%
Observation:
    Dataset contains 7 rows and 7 columns .
    Data types were verified.

# %%
df.describe()
# Out:
#                Item      Quantity  Price Per Unit   Total Spent
# count  10000.000000  10000.000000    10000.000000  10000.000000
# mean       4.053700      3.028463        2.949984      8.924352
# std        3.101125      1.384601        1.243910      5.857113
# min       -1.000000      1.000000        1.000000      1.000000
# 25%        1.000000      2.000000        2.000000      4.000000
# 50%        4.000000      3.000000        3.000000      8.000000
# 75%        7.000000      4.000000        4.000000     12.000000
# max        9.000000      5.000000        5.000000     25.000000

# %%
Observation:
    Average quantity purchased is 3.000000
    maximum purchased quantity is 5.000000

# %%
df.isnull().sum()
# Out:
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
Observation:
    No missing values found in the dataset.

# %%
df['Item'].value_counts()
# Out:
# Item
#  8    1171
#  0    1165
#  3    1148
#  1    1139
#  6    1131
#  4    1096
#  2    1092
#  9    1089
#  5     344
# -1     333
#  7     292
# Name: count, dtype: int64

# %%
Observation:
    Most sold item is 8

# %%
sns.countplot(y='Item', data=df)
plt.show()

# %%
Observation:
    least sold item is 7

# %%
sns.countplot(x='Payment Method', data=df)
plt.show()

# %%
Observation:
Most customer preferred Payment method.

# %%
plt.hist(df['Quantity'])
plt.show()

# %%
Observation:
Moast transactions contain 3.0 items

# %%
plt.hist(df['Total Spent'])
plt.show()

# %%
Observation:
Majority of customers spend between 1500 and 1750.

# %%
sns.boxplot(x=df['Total Spent'])
plt.show()

# %%
Observation:
    Outliers are present/not present in spending data.

# %%
sns.scatterplot(x='Quantity', y='Total Spent',data=df)
plt.show()

# %%
Observation:
     As quantity increases ,total spending also increases.

# %%
corr= df[['Quantity','Price Per Unit','Total Spent']].corr()

sns.heatmap(corr,annot=True,
cmap='coolwarm')
plt.show()

# %%
Observation:
    Total spent has a strong positve relationship with quantity and price per unit.

# %%
sns.pairplot(
    df[['Quantity','Price Per Unit','Total Spent']]
)
plt.show()

# %%
Observation:
    Positive trends can be observed between numerical variables.
    Quantity and totalspent show the strongest relationship.

# %%
SUMMARY OF FINDINGS
1.Dataset contains cafe transaction records.
2.No missing values were found.
3.Cofee/Tea (Actual result based on your dataset)was the mostsold item.
4.Card/Cash (actual result)was the most used payment method.
5.Quantity and Total Spent have a strong positive relationship.
6.A few high-spending transactions were identified as outliers.
7.Most customers purchased small quantities of items.
